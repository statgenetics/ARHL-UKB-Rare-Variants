# %% [markdown]
# # Figure S5. Q-Q plots for single variant association analysis of the mega sample
#
# Q-Q plots were generated using the pipeline `LMM.ipynb`. The following cells contains the chunk of code responsible for the generation of these plots.

# %%
plots <- function(file,trait,out){
library('qqman')
data <- read.table(gzfile(file), sep='\t', header=T)
lambda <- median(qchisq(1-data$P,1), na.rm=TRUE)/qchisq(0.5,1)
png(out, width = 5, height = 5, unit='in', res=300)
qq_plot <- qq(data$P, main = trait, xlim = c(0, 8), ylim = c(0, 16), pch = 18, col = "blue4", cex = 1.5, las = 1)
dev.off()
}

# %% [markdown]
# ## Panel A. H-aid

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_exome_data/090921_f3393_hearing_aid_200K/090321_UKBB_Hearing_aid_f3393_expandedwhite_6436cases_96601ctrl_PC1_2_f3393.regenie.snp_stats.gz"
trait <- "f3393"
out <- "~/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f3393_qqplot.png"
plots(file,trait,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f3393_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f3393_qqplot.png (61.8 KiB):

# %% [markdown]
# ## Panel B. H-diff

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_exome_data/090921_f2247_hearing_difficulty_200K/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_45502cases_96601ctrl_PC1_2_f2247.regenie.snp_stats.gz"
trait <- "f2247"
out <- "~/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f2247_qpplot.png"
plots(file,trait,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f2247_qpplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f2247_qpplot.png (61.1 KiB):

# %% [markdown]
# ## Panel C. H-noise

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_exome_data/090921_f2257_hearing_noise_200K/090321_UKBB_Hearing_noise_f2257_expandedwhite_65660cases_96601ctrl_PC1_2_f2257.regenie.snp_stats.gz"
trait <- "f2257"
out <- "~/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f2257_qqplot.png"
plots(file,trait,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f2257_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f2257_qqplot.png (61.8 KiB):

# %% [markdown]
# ## Panel D. H-both

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_exome_data/090921_combined_f2247_f2257_200K/090321_UKBB_Combined_f2247_f2257_expandedwhite_38410cases_96601ctrl_PC1_2_f2247_f2257.regenie.snp_stats.gz"
trait <- "f2247_f2257"
out <- "~/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f2247_f2257_qqplot.png"
plots(file,trait,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f2247_f2257_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_exome_data/042622_paper_manhattan/200k.f2247_f2257_qqplot.png (63.0 KiB):

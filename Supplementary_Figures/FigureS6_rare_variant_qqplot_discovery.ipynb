# %% [markdown]
# # Figure S6. Q-Q plots for rare-variant association analysis of the Discovery sample
#
# Q-Q plots were generated using the pipeline `LMM.ipynb`. The following cells contains the chunk of code responsible for the generation of these plots.

# %%
plots <- function(file,out){
library('qqman')
data <- read.table(gzfile(file), sep='\t', header=T)
lambda <- median(qchisq(1-data$P,1), na.rm=TRUE)/qchisq(0.5,1)
png(out, width = 5, height = 5, unit='in', res=300)
qq_plot <- qq(data$P, xlim = c(0, 8), ylim = c(0, 20), pch = 18, col = "blue4", cex = 1.5, las = 1)
dev.off()
}

# %% [markdown]
# ## H-aid
#
# ### Panel A top: pLoF - 0.01

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/150k/091321_f3393_hearing_aid/090321_UKBB_Hearing_aid_f3393_expandedwhite_78848ind_150K_f3393.regenie_burden.Mask1.0.01.remove_sin.snp_stats.gz"
out <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f3393.regenie_burden.Mask1.0.01_qqplot.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f3393.regenie_burden.Mask1.0.01_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f3393.regenie_burden.Mask1.0.01_qqplot.png (54.8 KiB):

# %% [markdown]
# ### Panel A bottom: pLoF + missense - 0.01

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/150k/091321_f3393_hearing_aid/090321_UKBB_Hearing_aid_f3393_expandedwhite_78848ind_150K_f3393.regenie_burden.Mask2.0.01.remove_sin.snp_stats.gz"
out <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f3393.regenie_burden.Mask2.0.01_qqplot.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f3393.regenie_burden.Mask2.0.01_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f3393.regenie_burden.Mask2.0.01_qqplot.png (54.8 KiB):

# %% [markdown]
# ## H-diff
#
# ### Panel B top: pLoF - 0.01

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/150k/090321_f2247_hearing_difficulty/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_107507ind_150K_f2247.regenie_burden.Mask2.0.01.remove_sin.snp_stats.gz"
out <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247.regenie_burden.Mask2.0.01_qqplot.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247.regenie_burden.Mask2.0.01_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247.regenie_burden.Mask2.0.01_qqplot.png (54.7 KiB):

# %% [markdown]
# ### Panel B bottom: pLoF + missense - 0.01

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/150k/090321_f2247_hearing_difficulty/090321_UKBB_Hearing_difficulty_f2247_expandedwhite_107507ind_150K_f2247.regenie_burden.Mask1.0.01.remove_sin.snp_stats.gz"
out <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247.regenie_burden.Mask1.0.01_qqplot.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247.regenie_burden.Mask1.0.01_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247.regenie_burden.Mask1.0.01_qqplot.png (54.7 KiB):

# %% [markdown]
# ## H-noise
#
# ### Panel C top: pLoF - 0.01

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/150k/090321_f2257_hearing_noise/090321_UKBB_Hearing_noise_f2257_expandedwhite_123538ind_150K_f2257.regenie_burden.Mask1.0.01.remove_sin.snp_stats.gz"
out <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2257.regenie_burden.Mask1.0.01_qqplot.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2257.regenie_burden.Mask1.0.01_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2257.regenie_burden.Mask1.0.01_qqplot.png (54.6 KiB):

# %% [markdown]
# ### Panel C bottom :pLoF + missense - 0.01

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/150k/090321_f2257_hearing_noise/090321_UKBB_Hearing_noise_f2257_expandedwhite_123538ind_150K_f2257.regenie_burden.Mask2.0.01.remove_sin.snp_stats.gz"
out <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2257.regenie_burden.Mask2.0.01_qqplot.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2257.regenie_burden.Mask2.0.01_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2257.regenie_burden.Mask2.0.01_qqplot.png (54.5 KiB):

# %% [markdown]
# ## H-both
#
# ### Panel D top: pLoF - 0.01

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/150k/090321_Combined_f2247_f2257/090321_UKBB_Combined_f2247_f2257_expandedwhite_102133ind_150K_f2247_f2257.regenie_burden.Mask1.0.01.remove_sin.snp_stats.gz"
out <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247_f2257.regenie_burden.Mask1.0.01_qqplot.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247_f2257.regenie_burden.Mask1.0.01_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247_f2257.regenie_burden.Mask1.0.01_qqplot.png (54.6 KiB):

# %% [markdown]
# ### Panel D bottom: pLoF + missense - 0.01

# %%
file <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/150k/090321_Combined_f2247_f2257/090321_UKBB_Combined_f2247_f2257_expandedwhite_102133ind_150K_f2247_f2257.regenie_burden.Mask2.0.01.remove_sin.snp_stats.gz"
out <- "~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247_f2257.regenie_burden.Mask2.0.01_qqplot.png"
plots(file,out)
# Out:
# png
#   2

# %%
%preview ~/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247_f2257.regenie_burden.Mask2.0.01_qqplot.png -n
# Out:
# > /home/dmc2245/UKBiobank/results/REGENIE_results/results_burden_exome/040822_paper_manhattan/150K_f2247_f2257.regenie_burden.Mask2.0.01_qqplot.png (54.7 KiB):
